# %% [markdown]
# # FDS Assignment 1: UN Debates, World Happiness and International Trade
#
# We can start by loading the data:

# %%
import os
import numpy as np
import pandas as pd

sessions = np.arange(25, 76)
data=[]

for session in sessions:
    directory = "./TXT/Session " + str(session) + " - " + str(1945 + session)
    for filename in os.listdir(directory):
        f = open(os.path.join(directory, filename), encoding='utf8')
        if filename[0] == ".":
            continue
        splt = filename.split("_")
        data.append([session, 1945 + session, splt[0], f.read()])

df_speech = pd.DataFrame(data, columns=['Session','Year','ISO-alpha3 Code','Speech'])
df_speech.head(50)
# Out:
#     Session  Year ISO-alpha3 Code  \
# 0        25  1970             ALB
# 1        25  1970             ARG
# 2        25  1970             AUS
# 3        25  1970             AUT
# 4        25  1970             BEL
# 5        25  1970             BLR
# 6        25  1970             BOL
# 7        25  1970             BRA
# 8        25  1970             CAN
# 9        25  1970             CMR
# 10       25  1970             COG
# 11       25  1970             COL
# 12       25  1970             CRI
# 13       25  1970             CUB
# 14       25  1970             DOM
# 15       25  1970             DZA
# 16       25  1970             ECU
# 17       25  1970             FRA
# 18       25  1970             GBR
# 19       25  1970             GHA
# 20       25  1970             GIN
# 21       25  1970             GMB
# 22       25  1970             GTM
# 23       25  1970             HND
# 24       25  1970             HTI
# 25       25  1970             IDN
# 26       25  1970             IND
# 27       25  1970             IRN
# 28       25  1970             IRQ
# 29       25  1970             ISL
# 30       25  1970             ISR
# 31       25  1970             ITA
# 32       25  1970             JPN
# 33       25  1970             KEN
# 34       25  1970             KHM
# 35       25  1970             KWT
# 36       25  1970             LBN
# 37       25  1970             LBR
# 38       25  1970             LBY
# 39       25  1970             LKA
# 40       25  1970             MAR
# 41       25  1970             MDG
# 42       25  1970             MEX
# 43       25  1970             MMR
# 44       25  1970             NLD
# 45       25  1970             NOR
# 46       25  1970             NZL
# 47       25  1970             PAK
# 48       25  1970             PER
# 49       25  1970             PHL
#
#                                                Speech
# 0   33: May I first convey to our President the co...
# 1   177.\t : It is a fortunate coincidence that pr...
# 2   100.\t  It is a pleasure for me to extend to y...
# 3   155.\t  May I begin by expressing to Ambassado...
# 4   176. No doubt each of us, before coming up to ...
# 5   71.\t. We are today mourning the untimely deat...
# 6   135.\t  I wish to congratulate the President o...
# 7   1.\tMr. President, I should like, first of all...
# 8   The General Assembly is fortunate indeed to ha...
# 9   : A year ago I came here as the Acting Preside...
# 10  122.\t  I cannot begin my intervention without...
# 11  Mr. President, this visit to the United Nation...
# 12  62.\t  Mr. President, your election to the Pre...
# 13  1.\t  Mr. President, I should first like to co...
# 14  Mr. President, it was a source of great pleasu...
# 15  1.  The delegation of Algeria is very pleased ...
# 16  71.  It had been my hope that a loftier person...
# 17  84.\t  Within one month, when we celebrate the...
# 18  110.\t Mr. President, I should like first to s...
# 19  121.\t I should like to begin by congratulatin...
# 20  35.\t  The delegation of the Republic of Guine...
# 21  Mr. President, permit me, first of all, to off...
# 22  196.\tBefore starting my statement may I, by y...
# 23  153.\t  This session of the General Assembly w...
# 24  1.\t  Mr. President, I hardly need to emphasiz...
# 25  101.\tOn behalf of the Indonesian delegation, ...
# 26  40.\t Mr. President, I offer you our congratul...
# 27  31.\tMr. President, it is only fitting that on...
# 28  133.\tI should like, on behalf of the delegati...
# 29  Mr. President, allow me, on behalf of the Icel...
# 30  93.\tMr. President, your country, Norway, has ...
# 31  72.\t  Mr. President, I trust I may be allowed...
# 32  53. Mr. President, on behalf of the Japanese d...
# 33  36.\t Mr. President, on behalf of His Excellen...
# 34  4.\t Before I begin this speech I should like ...
# 35  1.\t   Mr. President, your election to the aug...
# 36  1.\t Mr. President, it is a particular pleasur...
# 37  49.\t It gives me great pleasure, Mr. Presiden...
# 38  110.\t  Sir, allow me first to offer on behalf...
# 39  176.\t Mr. President, the delegation of Ceylon...
# 40  81.\t  Mr. President, on the threshold of this...
# 41  5.\t Our delegation has more than one reason t...
# 42  33.\t  Mr. President, I take great pleasure in...
# 43  32.\t The delegation of Burma would like first...
# 44  141.\t As my opening remark I should like as m...
# 45  113.\t Mr. President, I am happy to congratula...
# 46  180.\t At the outset, I should like to refer t...
# 47  60.\t  Recognizing Ambassador Hambro's long an...
# 48  1.\t  Mr. President, may I start my statement ...
# 49  36.\t May I say to the delegation of Malaysia ...

# %%
import nltk

nltk.download('punkt')
nltk.download('stopwords')
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\agniv\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\agniv\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\agniv\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
import re
import string

def preprocess(speech):
    sentences = speech.split("\n")
    new_speech = []
    for sentence in sentences:
        sentence = re.sub('(\d+)[:.]\s', '', sentence)
        sentence = sentence.translate(str.maketrans('', '', string.punctuation))
        sentence = sentence.lower()
        # tokens_without_sw = [word for word in sentence if not word in stopwords.words("english")]
        new_speech.append(sentence)
    print(new_speech)
    return ' '.join(new_speech)

# %%
# from nltk import word_tokenize

df_1970 = df_speech.set_index(["Year", "ISO-alpha3 Code"]).loc[1970]
speeches_1970 = df_1970['Speech']

## ['', '', ... ]
# speeches = [word_tokenize(speech) for speech in text.values]
processed_speeches = []
for speech in speeches_1970.values:
    processed_speeches.append(preprocess(speech))

print(processed_speeches)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# ## TF-IDF
#
# *Tf* means term-frequency while *tf-idf* means term-frequency times inverse document-frequency. This is a common term weighting scheme in information retrieval that has also found good use in document classification. The goal of using tf-idf instead of the raw frequencies of occurrence of a token in a given document (as in the previous example) is to scale down the impact of tokens that occur very frequently in a given corpus and that are hence empirically less informative than features that occur in a small fraction of the training corpus. If needed, more info can be found [here](https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfTransformer.html).

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(speeches_1970.values)
feature_names = vectorizer.get_feature_names()
dense = X.todense()
denselist = dense.tolist()

print(pd.DataFrame(denselist, columns=feature_names))
# Out:
#          000  054        10       100       101  101st       102       103  \
# 0   0.000000  0.0  0.000000  0.000000  0.000000    0.0  0.000000  0.000000
# 1   0.000000  0.0  0.002787  0.000000  0.000000    0.0  0.000000  0.000000
# 2   0.003554  0.0  0.000000  0.003323  0.003731    0.0  0.003731  0.003731
# 3   0.000000  0.0  0.006018  0.000000  0.000000    0.0  0.000000  0.000000
# 4   0.000000  0.0  0.003395  0.004191  0.000000    0.0  0.000000  0.000000
# ..       ...  ...       ...       ...       ...    ...       ...       ...
# 65  0.000000  0.0  0.002637  0.000000  0.000000    0.0  0.000000  0.000000
# 66  0.000000  0.0  0.000000  0.005021  0.005636    0.0  0.005636  0.005636
# 67  0.000000  0.0  0.000000  0.005643  0.006335    0.0  0.006335  0.006335
# 68  0.015939  0.0  0.004024  0.000000  0.000000    0.0  0.000000  0.000000
# 69  0.000000  0.0  0.003347  0.004131  0.004637    0.0  0.004637  0.004637
#
#          104       105  ...  zeal  zealand  zealous  zimbabwe   zionism  \
# 0   0.000000  0.000000  ...   0.0      0.0      0.0  0.000000  0.002818
# 1   0.000000  0.000000  ...   0.0      0.0      0.0  0.000000  0.000000
# 2   0.003731  0.003731  ...   0.0      0.0      0.0  0.000000  0.000000
# 3   0.000000  0.000000  ...   0.0      0.0      0.0  0.000000  0.000000
# 4   0.000000  0.000000  ...   0.0      0.0      0.0  0.000000  0.000000
# ..       ...       ...  ...   ...      ...      ...       ...       ...
# 65  0.000000  0.000000  ...   0.0      0.0      0.0  0.000000  0.000000
# 66  0.005636  0.005636  ...   0.0      0.0      0.0  0.000000  0.000000
# 67  0.006335  0.006335  ...   0.0      0.0      0.0  0.000000  0.000000
# 68  0.000000  0.000000  ...   0.0      0.0      0.0  0.000000  0.000000
# 69  0.004637  0.004637  ...   0.0      0.0      0.0  0.004637  0.000000
#
#      zionist  zionistamerican  zionists      zone  zones
# 0   0.004977              0.0  0.008897  0.000000    0.0
# 1   0.000000              0.0  0.000000  0.003679    0.0
# 2   0.000000              0.0  0.000000  0.003554    0.0
# 3   0.000000              0.0  0.000000  0.000000    0.0
# 4   0.000000              0.0  0.000000  0.000000    0.0
# ..       ...              ...       ...       ...    ...
# 65  0.000000              0.0  0.000000  0.000000    0.0
# 66  0.000000              0.0  0.000000  0.000000    0.0
# 67  0.000000              0.0  0.000000  0.000000    0.0
# 68  0.000000              0.0  0.000000  0.000000    0.0
# 69  0.000000              0.0  0.000000  0.000000    0.0
#
# [70 rows x 11521 columns]
